# %% [markdown]
# # CSE-221710313005-Akhila Shankar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0         13.50          15.64            86.97       549.1            0.1385
# 1         11.88          22.94            78.28       424.8            0.1213
# 2         12.41          26.44            79.93       471.4            0.1369
# 3         11.92          15.77            76.53       434.0            0.1367
# 4         16.20          15.73           104.50       819.1            0.1126
#
#    compactness_worst  concavity_worst  points_worst  symmetry_worst  \
# 0             0.1266          0.12420       0.09391          0.2827
# 1             0.2515          0.19160       0.07926          0.2940
# 2             0.1482          0.10670       0.07431          0.2998
# 3             0.1822          0.08669       0.08611          0.2102
# 4             0.1737          0.13620       0.08178          0.2487
#
#    dimension_worst
# 0          0.06771
# 1          0.07587
# 2          0.07881
# 3          0.06784
# 4          0.06766
#
# [5 rows x 32 columns]

# %%
#Check the descriptive statistics of the dataset
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# count       569.000000        569.000000      569.000000   569.000000
# mean          0.096360          0.104341        0.088799     0.048919
# std           0.014064          0.052813        0.079720     0.038803
# min           0.052630          0.019380        0.000000     0.000000
# 25%           0.086370          0.064920        0.029560     0.020310
# 50%           0.095870          0.092630        0.061540     0.033500
# 75%           0.105300          0.130400        0.130700     0.074000
# max           0.163400          0.345400        0.426800     0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        points_worst  symmetry_worst  dimension_worst
# count    569.000000      569.000000       569.000000
# mean       0.114606        0.290076         0.083946
# std        0.065732        0.061867         0.018061
# min        0.000000        0.156500         0.055040
# 25%        0.064930        0.250400         0.071460
# 50%        0.099930        0.282200         0.080040
# 75%        0.161400        0.317900         0.092080
# max        0.291000        0.663800         0.207500
#
# [8 rows x 31 columns]

# %%
#Visualize some of those columns and find out if you observe any pattern
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05A4AA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05AACFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05AE74C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05B1E188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05B4FEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05B85C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05BC0608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05BFA708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05C06308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05C3D4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05CA4A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05CDDB08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05D13C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05D4CD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05D86E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05DBEF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05DFD048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05E34148>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05E6F288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05EA73C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05EDF4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05F19548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05F56E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05F88788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05FC0888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE05FFB9C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE06032AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE0606AB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE060A4C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE060DDD88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE06115E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE0614DFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE0618C148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE061C5308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE061FD508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE062376C8>]],
#       dtype=object)

# %%
for i in data.select_dtypes(include=['int64','float64']).columns:
    sns.boxplot(data[i])
    plt.show()

# %%
#Find the correlation in the data and visualize it
corr=data.corr()

# %%
plt.subplots(figsize=(25,25))
sns.heatmap(corr,annot=True)

# %%
#Visualize the frequency of the output categories
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data['diagnosis'].value_counts().plot(kind='bar')

# %%
# Apply the KNN Algorithm to the dataset without applying scaling operation and try to compare the 
# results before scaling and after scaling.
X = data.drop(['id','diagnosis'],axis=1)
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        12.32         12.39           78.85      464.1          0.10280
# 1        10.60         18.95           69.28      346.4          0.09688
# 2        11.04         16.83           70.92      373.2          0.10770
# 3        11.28         13.39           73.00      384.8          0.11640
# 4        15.19         13.21           97.65      711.8          0.07963
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0           0.06981         0.03987      0.03700         0.1959
# 1           0.11470         0.06387      0.02642         0.1922
# 2           0.07804         0.03046      0.02480         0.1714
# 3           0.11360         0.04635      0.04796         0.1771
# 4           0.06934         0.03393      0.02657         0.1721
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.05955  ...         13.50          15.64            86.97
# 1         0.06491  ...         11.88          22.94            78.28
# 2         0.06340  ...         12.41          26.44            79.93
# 3         0.06072  ...         11.92          15.77            76.53
# 4         0.05544  ...         16.20          15.73           104.50
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       549.1            0.1385             0.1266          0.12420
# 1       424.8            0.1213             0.2515          0.19160
# 2       471.4            0.1369             0.1482          0.10670
# 3       434.0            0.1367             0.1822          0.08669
# 4       819.1            0.1126             0.1737          0.13620
#
#    points_worst  symmetry_worst  dimension_worst
# 0       0.09391          0.2827          0.06771
# 1       0.07926          0.2940          0.07587
# 2       0.07431          0.2998          0.07881
# 3       0.08611          0.2102          0.06784
# 4       0.08178          0.2487          0.06766
#
# [5 rows x 30 columns]

# %%
y = data.diagnosis
y.head()
# Out:
# 0    B
# 1    B
# 2    B
# 3    B
# 4    B
# Name: diagnosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=24)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (398, 30)
# (171, 30)
# (398,)
# (171,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Scaling for training data
scaled_X_train = pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns)
scaled_X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0      -0.782351     -0.889313       -0.793012  -0.744846         0.006441
# 1       0.629624     -0.819069        0.536516   0.489409        -0.142368
# 2      -1.597644     -1.705045       -1.579636  -1.260000         0.085759
# 3       0.470160      0.211927        0.448273   0.317495         0.435320
# 4      -0.486619     -0.819069       -0.393397  -0.517684         2.211201
# ..           ...           ...             ...        ...              ...
# 393    -0.672177     -0.436128       -0.700147  -0.659329         0.308972
# 394    -0.219881     -0.662720       -0.245065  -0.293167        -1.765229
# 395    -0.820043     -0.254854       -0.756454  -0.775408        -0.026550
# 396     0.229516     -0.993545        0.189847   0.098856        -1.075232
# 397     1.760363      1.702905        1.755110   1.706619         0.193154
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0           -0.650788       -0.653479    -0.515981      -0.282407
# 1           -0.684104       -0.396636    -0.079984      -0.364845
# 2           -0.955150       -0.836557    -1.057128      -0.465204
# 3            0.318767        0.358023     0.410512       0.438025
# 4            1.252370        0.905227     0.830753       0.982829
# ..                ...             ...          ...            ...
# 393         -0.900564       -0.799485    -0.857443      -0.339755
# 394         -0.568721       -0.070853    -0.535353      -1.400690
# 395          0.546521        0.867139    -0.521405       0.864549
# 396         -0.338332       -0.394985    -0.426612      -0.450867
# 397          1.194020        0.985213     2.008822       0.222970
#
#      dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         -0.548326  ...     -0.834790      -0.590901        -0.825385
# 1         -0.835158  ...      0.224625      -1.284523         0.080491
# 2          1.274712  ...     -1.430817      -1.668783        -1.432840
# 3          0.055676  ...      0.699244       0.755638         0.568760
# 4          1.862166  ...     -0.167358      -0.309219        -0.113604
# ..              ...  ...           ...            ...              ...
# 393       -0.665541  ...     -0.781819       0.135286        -0.836303
# 394       -0.606244  ...     -0.423737      -0.472041        -0.459638
# 395        1.939390  ...     -0.779701       0.376262        -0.606119
# 396       -0.818610  ...      0.194962      -1.209625         0.147211
# 397       -0.334581  ...      1.680262       1.328771         1.602919
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0     -0.743841         -0.562708          -0.545979        -0.599706
# 1      0.091742          0.149361          -0.725602        -0.337832
# 2     -1.079185          1.794934          -0.801958        -0.710095
# 3      0.378156          1.009053           1.226475         0.631773
# 4     -0.242706          2.046763           1.707766         1.290760
# ..          ...               ...                ...              ...
# 393   -0.694552          0.158045          -0.951540        -0.847579
# 394   -0.438966         -1.279118           0.006661         0.312554
# 395   -0.724305          0.118968           1.456794         2.285214
# 396    0.053028         -1.105443           0.169386         0.237527
# 397    1.423082         -0.180622           0.560553         0.501313
#
#      points_worst  symmetry_worst  dimension_worst
# 0       -0.445582       -0.355805        -0.887367
# 1        0.328777       -0.935814        -0.625475
# 2       -1.062302        0.483358         0.386046
# 3        0.514234        1.675771         1.295064
# 4        0.912511        1.663431         2.308838
# ..            ...             ...              ...
# 393     -1.079480        0.452507        -0.993813
# 394     -0.369271       -1.324544        -0.401318
# 395      0.117478        0.619105         2.607339
# 396      0.009548       -0.337294        -0.038049
# 397      1.537288        0.562030        -0.399065
#
# [398 rows x 30 columns]

# %%
# Scaling for testing data
# Testing the data based on training data
scaled_X_test = pd.DataFrame(scaler.fit_transform(X_test),columns=X_test.columns)
scaled_X_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.261329      0.547787        1.216337   1.150595        -0.393374
# 1      -0.261959      0.326052       -0.315281  -0.318579        -1.704211
# 2      -1.180548     -0.558393       -1.165479  -0.978420         0.529584
# 3      -0.321696     -0.762688       -0.349983  -0.401159         0.168202
# 4       1.054966      0.331035        1.038884   0.924895         0.264620
# ..           ...           ...             ...        ...              ...
# 166    -0.726277      0.433182       -0.719480  -0.682886         1.007991
# 167     0.210505      0.821840        0.396109   0.069890         0.218251
# 168    -0.856611     -0.506074       -0.801503  -0.762545        -0.541313
# 169    -1.186521      2.234462       -1.197815  -0.976561        -1.226539
# 170     1.120133      0.186534        1.086205   1.012520        -0.137978
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0            0.652148        0.145543     0.296568       0.550814
# 1           -1.034166       -0.935232    -0.946497      -0.366502
# 2           -0.430795       -0.624018    -0.812264      -0.859559
# 3           -0.347492       -0.751500    -0.654888      -0.282414
# 4            0.434248        0.280640     0.726524       1.173825
# ..                ...             ...          ...            ...
# 166         -0.246062       -0.592454    -0.695261       0.126556
# 167          2.239153        2.200243     1.227710       0.887163
# 168          0.094864        0.005165    -0.340393      -1.222663
# 169         -1.159313       -0.967041    -1.001270      -0.718140
# 170          0.050513        0.227829     0.633435      -0.056908
#
#      dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         -0.361052  ...      1.625615       1.405463         1.533795
# 1         -0.658568  ...     -0.352925       0.442680        -0.350434
# 2          1.137208  ...     -1.032802      -0.696044        -1.026420
# 3         -0.182542  ...     -0.479047      -0.443537        -0.510770
# 4         -0.370206  ...      1.032447       0.051702         1.027020
# ..              ...  ...           ...            ...              ...
# 166        1.045664  ...     -0.626847       1.045438        -0.658508
# 167        0.882412  ...      0.011646       0.297692         0.511656
# 168        0.488776  ...     -0.774646       0.183657        -0.497886
# 169       -0.560922  ...     -1.107687       1.820878        -1.130925
# 170       -0.881324  ...      1.298486       0.312354         1.307607
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      1.658377          0.740194           1.479486         0.852889
# 1     -0.405431         -0.966522          -0.628611        -1.026098
# 2     -0.879465          0.600962          -0.549748        -0.768285
# 3     -0.519011         -0.723989          -0.421844        -0.520295
# 4      0.905113         -0.108672          -0.177302        -0.163384
# ..          ...               ...                ...              ...
# 166   -0.613042          1.005184          -0.608730        -0.547039
# 167   -0.094689          0.385377           2.979211         2.985118
# 168   -0.695109          0.259619           0.985763         0.923396
# 169   -0.908281         -1.002453          -0.984489        -1.050800
# 170    1.208441          0.488678          -0.012286         0.439572
#
#      points_worst  symmetry_worst  dimension_worst
# 0        1.360021        1.463129         0.723986
# 1       -1.129906       -0.369531        -0.585400
# 2       -0.955756       -0.654037        -0.028066
# 3       -0.488809        0.757407        -0.368152
# 4        0.505327        0.672425        -0.480263
# ..            ...             ...              ...
# 166     -0.834509       -0.230973         0.177380
# 167      2.012891       -0.038839         1.625160
# 168      0.606239       -0.641105         0.542678
# 169     -1.027312       -1.045694        -0.702338
# 170      1.182661        0.325106        -0.081707
#
# [171 rows x 30 columns]

# %%
# Model Building
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6,metric='euclidean')
knn.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')

# %%
# Without Scaling
knn1 = KNeighborsClassifier(n_neighbors=6,metric='euclidean')
knn1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')

# %%
# Predictions on the data
y_train_pred = knn.predict(scaled_X_train)
y_train_pred
# Out:
# array(['B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M'], dtype=object)

# %%
#predicting Without Scaling
y_train_pred1 = knn1.predict(X_train)
y_train_pred1
# Out:
# array(['B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M'], dtype=object)

# %%
#classification_report
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      1.00      0.97       252
#            M       0.99      0.91      0.95       146
#
#     accuracy                           0.96       398
#    macro avg       0.97      0.95      0.96       398
# weighted avg       0.97      0.96      0.96       398

# %%
# Without Scaling :
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.92      0.99      0.95       252
#            M       0.98      0.85      0.91       146
#
#     accuracy                           0.94       398
#    macro avg       0.95      0.92      0.93       398
# weighted avg       0.94      0.94      0.94       398

# %%
# Checking for optimum k-value
# Build the models with multiple k values
from sklearn.metrics import accuracy_score
scores =[]
for k in range(1,20):
    knn_model = KNeighborsClassifier(n_neighbors=k)#,metric='euclidean')
    knn_model.fit(scaled_X_train,y_train)
    pred_test = knn_model.predict(scaled_X_test)
    scores.append(accuracy_score(y_test,pred_test))
scores
# Out:
# [0.9649122807017544,
#  0.9532163742690059,
#  0.9766081871345029,
#  0.9590643274853801,
#  0.9766081871345029,
#  0.9649122807017544,
#  0.9649122807017544,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9532163742690059,
#  0.9532163742690059,
#  0.9415204678362573,
#  0.9473684210526315,
#  0.9415204678362573,
#  0.9473684210526315,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573]

# %%
# Without Scaling
from sklearn.metrics import accuracy_score
scores1 =[]
for k in range(1,20):
    knn_model1 = KNeighborsClassifier(n_neighbors=k)#,metric='euclidean')
    knn_model1.fit(X_train,y_train)
    pred_test1 = knn_model1.predict(X_test)
    scores1.append(accuracy_score(y_test,pred_test1))
scores1
# Out:
# [0.9239766081871345,
#  0.9181286549707602,
#  0.9415204678362573,
#  0.9122807017543859,
#  0.935672514619883,
#  0.9122807017543859,
#  0.9239766081871345,
#  0.9064327485380117,
#  0.935672514619883,
#  0.9181286549707602,
#  0.9298245614035088,
#  0.9298245614035088,
#  0.935672514619883,
#  0.9298245614035088,
#  0.935672514619883,
#  0.935672514619883,
#  0.935672514619883,
#  0.9298245614035088,
#  0.9298245614035088]

# %%
# Plot of K values and Scores
plt.plot(range(1,20),scores,marker='o',markerfacecolor='r',linestyle='--')

# %%
#Without Scaling
plt.plot(range(1,20),scores1,marker='o',markerfacecolor='r',linestyle='--')

# %%
final_model = KNeighborsClassifier(n_neighbors=7,metric='euclidean')
final_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
# Without Scaling
final_model1 = KNeighborsClassifier(n_neighbors=9,metric='euclidean')
final_model1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                      weights='uniform')

# %%
# Prediction on training data
final_train_pred = final_model.predict(scaled_X_train)
final_train_pred
# Out:
# array(['B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M'], dtype=object)

# %%
#Without Scaling
final_train_pred1 = final_model1.predict(X_train)
final_train_pred1
# Out:
# array(['B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_train,final_train_pred),annot=True,fmt='d')

# %%
#Without Scaling
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_train,final_train_pred1),annot=True,fmt='d')

# %%
# classification report
# Precision--> PPV --> Out of the positive predicted values,how many truely positive
print(classification_report(y_train,final_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      1.00      0.97       252
#            M       0.99      0.91      0.95       146
#
#     accuracy                           0.96       398
#    macro avg       0.97      0.95      0.96       398
# weighted avg       0.97      0.96      0.96       398

# %%
# Without Scaling
print(classification_report(y_train,final_train_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.97      0.95       252
#            M       0.94      0.88      0.91       146
#
#     accuracy                           0.93       398
#    macro avg       0.94      0.92      0.93       398
# weighted avg       0.93      0.93      0.93       398

# %%
# Prediction on Test Data
final_test_pred = final_model.predict(scaled_X_test) #y_test
final_test_pred
# Out:
# array(['M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M'], dtype=object)

# %%
final_test_pred1 = final_model1.predict(X_test) #y_test
final_test_pred1
# Out:
# array(['M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M'], dtype=object)

# %%
# Compare actual values of test data(y_test) and final_test_pred(model predicted values)
#Confusion_matrix(actualValues,predictedValues)
sns.heatmap(confusion_matrix(y_test,final_test_pred),annot=True,fmt='d')

# %%
# Without Scaling
sns.heatmap(confusion_matrix(y_test,final_test_pred1),annot=True,fmt='d')

# %%
print(classification_report(y_test,final_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      1.00      0.97       105
#            M       1.00      0.91      0.95        66
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.95      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %%
#Without Scaling
print(classification_report(y_test,final_test_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.97      0.95       105
#            M       0.95      0.88      0.91        66
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.93      0.93       171
# weighted avg       0.94      0.94      0.94       171
